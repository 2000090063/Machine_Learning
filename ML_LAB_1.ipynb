# %% [markdown]
# <a href="https://colab.research.google.com/github/2000090063/Machine_Learning/blob/main/ML_LAB_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from random import randint
from math import pi as PI
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
plt.style.use('ggplot')

# %%
NUM_OBS = 500

# %%
x=np.linspace(0,2,num=NUM_OBS)
eps =np.random.normal(0,1,NUM_OBS)
y = np.sin(PI*x)+eps

# %%
fig=plt.figure(figsize=(7,7))
ax=plt.axes()
ax.set_title('y=sin(PI*x)+ε')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.scatter(x,y,c='k')

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
fig=plt.figure(figsize=(7,7))
ax=plt.axes()
ax.set_title('y=sin(PI*x)+E')
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.scatter(x_train, y_train, label="Train set")
ax.scatter(x_train, y_train, label="Test set")
ax.legend()

# %%
NUM_MODELS=25
